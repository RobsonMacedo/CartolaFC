# %%
import cartolafc
import pprint
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Criando um objeto para trabalhar
# Logando para acessar todas as funcionalidades
api = cartolafc.Api()
login = api.set_credentials('robson.s.macedo@gmail.com', 'bradesco11')

# %%
# extraindo dados dos clubes
# extraindo dados das partidas
# extraindo dados dos atletas
# trazendo meus dados para comprar de acordo com a minha realidade
# Armazenando os dados das pontuacoes dos atletas em uma lista
clubes = api.clubes()
# trocar esse range final em cada rodada
partidas = [api.partidas(i) for i in range(1, 27)]
atletas = api.mercado_atletas()
meusDados = api.time_logado() 
IdsAtletas = [x.id for x in atletas]
pontuacoesAtletas = [api.pontuacao_atleta(i) for i in IdsAtletas]

# %%
# montar dicionario para facilitar montagem do Dataframe de PONTUACOES
atleta_id = list()
rodada_id  =list()
pontos = list()
preco = list()
variacao = list()
media = list()
for i in pontuacoesAtletas:
    for j in i:
        atleta_id.append(j.atleta_id)
        rodada_id.append(j.rodada_id)
        pontos.append(j.pontos)
        preco.append(j.preco)
        variacao.append(j.variacao)
        media.append(j.media)
        
pontuacoesAtletas_dict = {}
pontuacoesAtletas_dict['atleta_id'] = atleta_id
pontuacoesAtletas_dict['rodada_id'] = rodada_id
pontuacoesAtletas_dict['pontos'] = pontos
pontuacoesAtletas_dict['preco'] = preco
pontuacoesAtletas_dict['variacao'] = variacao
pontuacoesAtletas_dict['media'] = media

# Montando o DF para as pontuações dos atletas
pontuacoesAtletas_df = pd.DataFrame(pontuacoesAtletas_dict)

# %%
# testes até nas proximas 4linhas
pontuacoesAtletas_df.groupby('atleta_id')['media'].mean().max()
# Out:
# 12.024166666666666

# %%
pontuacoesAtletas_df[pontuacoesAtletas_df.media == 12.02]
# Out:
#       atleta_id  rodada_id  pontos  preco  variacao  media
# 5527      87863         21    16.7  19.33      1.28  12.02

# %%
for i in atletas:
    if i.id == 87863:
        print(i.apelido)
# Out:
# Arrascaeta

# %%
# preparando para criar o DF de dados dos ATLETAS
ident = list()
apelido = list()
pontos = list()
scout = list()
posicao = list()
clube = list()
status = list()
for i in atletas:
    ident.append(i.id)
    apelido.append(i.apelido)
    pontos.append(i.pontos)
    scout.append(i.scout)
    posicao.append(i.posicao[2])
    clube.append(i.clube.abreviacao)
    status.append(i.status[1])
    
# Criando o dicionario
atletas_dict = {}
atletas_dict['id'] = ident
atletas_dict['apelido'] = apelido
atletas_dict['ult_pontuacao']  =pontos
atletas_dict['scout'] = scout
atletas_dict['posicao'] = posicao
atletas_dict['clube'] = clube
atletas_dict['status'] = status

# Criando um DF para os atletas
atletas_df = pd.DataFrame(atletas_dict)

# %%
atletas[0]
# Out:
# {"id": 50294, "apelido": "Guilherme", "pontos": 0, "scout": {"CA": 2, "FC": 4, "FS": 3, "PE": 6, "RB": 2}, "posicao": [4, "Meia", "mei"], "clube": {"id": 266, "nome": "Fluminense", "abreviacao": "FLU"}, "status": [6, "Nulo"], "is_capitao": null}

# %%
atletas_df.head()
# Out:
#        id     apelido  ult_pontuacao  \
# 0  101728       Diego            0.0
# 1  101729     Fabinho            0.0
# 2  101720     Miranda            0.0
# 3  101717     Marrony            1.8
# 4  101837  Lucas Paes            0.0
#
#                                                scout posicao clube    status
# 0                                                 {}     zag   SAO      Nulo
# 1                                          {'FC': 1}     ata   SAO      Nulo
# 2               {'FC': 2, 'FS': 1, 'PE': 1, 'RB': 1}     zag   VAS      Nulo
# 3  {'A': 1, 'CA': 3, 'CV': 1, 'FC': 31, 'FD': 8, ...     ata   VAS  Suspenso
# 4                                                 {}     gol   SAO      Nulo

# %%
# montar um DF para partidas
data = list()
local = list()
clube_casa = list()
clube_casa_placar = list()
clube_visitante = list()
clube_visitante_placar = list()
for i in range(11, len(partidas)):
    for j in range(0, 9):
        data.append(partidas[i][j].data)
        local.append(partidas[i][j].local)
        clube_casa.append(partidas[i][j].clube_casa.abreviacao)
        clube_visitante.append(partidas[i][j].clube_visitante.abreviacao)
        if partidas[i][j].placar_casa == None or partidas[i][j].placar_visitante == None:
            clube_casa_placar.append(-1)
            clube_visitante_placar.append(-1)
        else:
            clube_casa_placar.append(partidas[i][j].placar_casa)
            clube_visitante_placar.append(partidas[i][j].placar_visitante)
        
partidas_dict = {}
partidas_dict['data'] = data
partidas_dict['local'] = local
partidas_dict['clube_casa'] = clube_casa
partidas_dict['clube_casa_placar'] = clube_casa_placar
partidas_dict['clube_visitante'] = clube_visitante
partidas_dict['clube_visitante_placar'] = clube_visitante_placar

partidas_df = pd.DataFrame(partidas_dict)

# %%
partidas[25][0]
# Out:
# {"data": {"year": 2019, "month": 10, "day": 16, "hour": 19, "minute": 15, "second": 0, "microsecond": 0, "tzinfo": null}, "local": "Arena do Gr\u00eamio", "clube_casa": {"id": 284, "nome": "Gr\u00eamio", "abreviacao": "GRE"}, "placar_casa": null, "clube_visitante": {"id": 265, "nome": "Bahia", "abreviacao": "BAH"}, "placar_visitante": null}

# %%
partidas_df.tail()
# Out:
#                    data            local clube_casa  clube_casa_placar  \
# 130 2019-10-16 21:00:00  Arena Palmeiras        PAL                 -1
# 131 2019-10-16 21:30:00     São Januário        VAS                 -1
# 132 2019-10-16 21:30:00    Serra Dourada        GOI                 -1
# 133 2019-10-17 19:15:00     Vila Belmiro        SAN                 -1
# 134 2019-10-17 19:15:00        Ressacada        AVA                 -1
#
#     clube_visitante  clube_visitante_placar
# 130             CHA                      -1
# 131             BOT                      -1
# 132             COR                      -1
# 133             CEA                      -1
# 134             INT                      -1

# %%
atletas_df.posicao.value_counts()
# Out:
# mei    274
# ata    187
# zag    130
# lat    117
# gol     98
# tec     19
# Name: posicao, dtype: int64

# %%
clubes_que_jogam_em_casa = partidas_df[partidas_df.clube_casa_placar == -1]['clube_casa'].values

# %%
clubes_que_jogam_em_casa
# Out:
# array(['GRE', 'CSA', 'FOR', 'CRU', 'PAL', 'VAS', 'GOI', 'SAN', 'AVA'],
#       dtype=object)

# %%
em_casa = []
for i, j in enumerate(atletas_df.clube):
    if j in clubes_que_jogam_em_casa:
        em_casa.append(1)
    else:
        em_casa.append(0)
atletas_df['em_casa'] = em_casa

# %%
clubes_que_jogam_em_casa
# Out:
# array(['GRE', 'CSA', 'FOR', 'CRU', 'PAL', 'VAS', 'GOI', 'SAN', 'AVA'],
#       dtype=object)

# %%
atletas_df.head()
# Out:
#       id     apelido  ult_pontuacao  \
# 0  50294   Guilherme            0.0
# 1  37614     Evandro            2.1
# 2  37246  Ney Franco            6.3
# 3  50284      Wilson            0.7
# 4  50313   Elicarlos            1.2
#
#                                                scout posicao clube    status  \
# 0      {'CA': 2, 'FC': 4, 'FS': 3, 'PE': 6, 'RB': 2}     mei   FLU      Nulo
# 1  {'A': 2, 'CV': 1, 'FC': 12, 'FD': 1, 'FF': 1, ...     mei   SAN  Provável
# 2                                                 {}     tec   GOI  Provável
# 3               {'DD': 8, 'FS': 1, 'GS': 9, 'PE': 2}     gol   ATL    Dúvida
# 4  {'CA': 4, 'FC': 18, 'FD': 2, 'FF': 7, 'FS': 14...     mei   CHA  Provável
#
#    em_casa
# 0        0
# 1        1
# 2        1
# 3        0
# 4        0

# %%
pontuacoesAtletas_df = pontuacoesAtletas_df.rename(columns={'atleta_id':'id'})

# %%
df_join.fillna(-1, inplace=True)

# %%
df_join = pd.merge(pontuacoesAtletas_df, atletas_df, on = 'id')

# %%
df_join = df_join.sort_values(by = ['rodada_id', 'pontos'], ascending=False)

# %%
df_join.fillna(0, inplace=True)

# %%
df_join.rodada_id.value_counts()
# Out:
# 23    825
# 15    825
# 22    825
# 14    825
# 21    825
# 20    825
# 19    825
# 18    825
# 25    825
# 17    825
# 24    825
# 16    825
# Name: rodada_id, dtype: int64

# %%
df_join.to_csv('rodada14A25.csv')

# %%
pontuacoesAtletas_df.to_csv('pontuacoes_rodada14A25.csv')

# %%
atletas_df.to_csv('atletas_rodada14A25.csv')

# %%
partidas_df.to_csv('partidas_rodada14A25.csv')

# %%
posicoes = ['mei', 'ata', 'zag', 'lat', 'gol', 'tec']

# %%
previsores = ['preco', 'media', 'em_casa']
classe = ['titular']

# %%
df_join[df_join.posicao =='mei']
# Out:
#           id  rodada_id  pontos  preco  variacao  media           apelido  \
# 3083   81845         25    11.4   9.23      1.72   5.87           Alisson
# 4763   91102         25    11.1   4.79      1.70   2.15            Flávio
# 5603   87999         25    10.5   6.48      1.18   3.46    Gustavo Scarpa
# 5963   93791         25     9.7   5.70      1.71   1.83            Daniel
# 1067   71844         25     9.5  13.03      1.24   6.08   Thiago Galhardo
# 2627   78855         25     9.2   6.39      0.79   2.40     Thiago Santos
# 9539   38913         25     9.0   7.50      0.21   3.47              Nenê
# 2567   78577         25     8.6   8.35      0.78   4.08        Ricardinho
# 9815   62009         25     8.0   7.35      0.65   2.64            Camilo
# 2591   80196         25     7.5   9.69      1.01   2.33      Yago Pikachu
# 8687  102999         25     7.4   4.54      1.44   1.42             Régis
# 5447   87552         25     7.3   6.53      0.82   2.81       Vitor Bueno
# 8207   38277         25     7.3   9.14      0.62   4.38      Thiago Neves
# 623    63219         25     7.2   8.40      1.30   3.65              Luan
# 8159   38196         25     6.6   8.14     -0.30   2.87            Maicon
# 5483   87747         25     6.2   5.66      0.20   3.26       Yago Felipe
# 5039   91733         25     6.0   7.00      0.49   2.65            Felipe
# 5279   93787         25     5.9   5.89      0.88   2.73            Andrey
# 491    37694         25     5.8   8.24      0.65   3.17          Henrique
# 3971  100761         25     5.4   4.63      0.59   1.50           Liziero
# 4751  101484         25     5.4   5.42      0.46   3.83   Thonny Anderson
# 9479   38648         25     5.2  13.76      0.05   4.28          Hernanes
# 5747   93108         25     5.0   7.68      0.51   4.15      Mateus Vital
# 5711  101889         25     4.9   3.02      1.54   3.20     Igor Goularte
# 2159   74140         25     4.8   6.82      0.56   3.28             Élber
# 2519   78605         25     4.4   6.53     -0.10   3.48           Gabriel
# 1907   70116         25     4.0   4.73     -0.06   3.04    Fellipe Bastos
# 2003   73858         25     3.9   3.24     -0.07   1.43       Jean Cléber
# 1271   72168         25     3.7   8.73     -1.32   3.15        João Paulo
# 5771   92981         25     3.7   4.91     -0.07   3.38           Ronaldo
# ...      ...        ...     ...    ...       ...    ...               ...
# 2196   70986         14    -1.1   5.47     -1.56   3.38     Léo Cittadini
# 2616   78855         14    -1.3   4.86     -0.35   1.33     Thiago Santos
# 4992   86766         14    -1.6   3.00     -0.78   1.60  Matheus Rossetto
# 9840   62104         14    -1.6   6.01     -0.26   1.12           Robinho
# 9408   38738         14    -1.7   4.59     -0.37  -0.42           Douglas
# 588    62977         14    -2.0   7.44     -0.97   2.21             Ganso
# 1692   73501         14    -2.0   1.55     -0.59   0.66           Julinho
# 96     50301         14    -2.3   6.81     -0.60   1.66           Everton
# 600    63178         14    -2.5   4.90     -0.38   1.38            Didira
# 9624   62023         14    -2.9   6.15     -0.70   1.26      D'Alessandro
# 948    71667         14    -3.8   2.84     -0.77   0.73           Geovane
# 9372   38545         14    -5.0   5.31     -1.98   0.60       Felipe Melo
# 6468   95464         14    -5.2   9.35     -1.13   2.42           Gregore
# 756    71233         14     0.0   0.00      0.00   0.00            Guarín
# 4680  101573         14     0.0   0.00      0.00   0.00              Pepê
# 4704  101375         14     0.0   0.00      0.00   0.00     Matheus Prado
# 4872   99459         14     0.0   0.00      0.00   0.00              Jean
# 5064   86749         14     0.0   0.00      0.00   0.00   Felipe Ferreira
# 5580   87929         14     0.0   0.00      0.00   0.00    Matheus Vargas
# 5700  101889         14     0.0   0.00      0.00   0.00     Igor Goularte
# 7020  105340         14     0.0   0.00      0.00   0.00            Flávio
# 7488   97315         14     0.0   0.00      0.00   0.00           Mantuan
# 7536   97993         14     0.0   0.00      0.00   0.00           Jhonata
# 7812  106000         14     0.0   0.00      0.00   0.00       Lucas Ramos
# 7848  106083         14     0.0   0.00      0.00   0.00             Breno
# 8016  106202         14     0.0   0.00      0.00   0.00       Bruno Gomes
# 8028  106219         14     0.0   0.00      0.00   0.00             Kawan
# 8052  106323         14     0.0   0.00      0.00   0.00    Caio Alexandre
# 8100  106312         14     0.0   0.00      0.00   0.00        Marx Lênin
# 9360  106199         14     0.0   0.00      0.00   0.00       Gabriel Pec
#
#       ult_pontuacao                                              scout  \
# 3083           11.4  {'A': 5, 'CA': 4, 'FC': 14, 'FD': 8, 'FF': 6, ...
# 4763           11.1  {'CA': 2, 'FC': 28, 'FD': 1, 'FF': 5, 'FS': 13...
# 5603           10.5  {'A': 3, 'CA': 1, 'FC': 12, 'FD': 14, 'FF': 14...
# 5963            9.7  {'A': 1, 'CA': 2, 'FC': 12, 'FD': 7, 'FF': 3, ...
# 1067            9.5  {'A': 1, 'CA': 2, 'FC': 25, 'FD': 17, 'FF': 24...
# 2627            9.2  {'CA': 3, 'FC': 24, 'FD': 1, 'FF': 1, 'FS': 8,...
# 9539            9.0  {'A': 2, 'CV': 1, 'FC': 15, 'FD': 3, 'FF': 12,...
# 2567            8.6  {'A': 5, 'CA': 1, 'FC': 22, 'FD': 15, 'FF': 18...
# 9815            8.0  {'A': 3, 'CA': 2, 'FC': 26, 'FD': 9, 'FF': 12,...
# 2591            7.5  {'A': 1, 'CA': 5, 'FC': 15, 'FD': 4, 'FF': 15,...
# 8687            7.4  {'CA': 1, 'FC': 8, 'FD': 4, 'FF': 9, 'FS': 4, ...
# 5447            7.3  {'FC': 7, 'FD': 2, 'FF': 6, 'FS': 15, 'FT': 2,...
# 8207            7.3  {'A': 2, 'CA': 6, 'FC': 18, 'FD': 14, 'FF': 24...
# 623             7.2  {'A': 1, 'CA': 4, 'FC': 26, 'FD': 4, 'FF': 13,...
# 8159            6.6  {'A': 2, 'CA': 4, 'FC': 11, 'FD': 1, 'FF': 2, ...
# 5483            6.2  {'A': 1, 'CA': 5, 'FC': 26, 'FD': 2, 'FF': 3, ...
# 5039            6.0  {'A': 1, 'CA': 8, 'FC': 42, 'FD': 2, 'FF': 3, ...
# 5279            5.9  {'CA': 1, 'FC': 13, 'FD': 3, 'FF': 5, 'FS': 9,...
# 491             5.8  {'CA': 3, 'FC': 29, 'FD': 3, 'FF': 10, 'FS': 3...
# 3971            5.4  {'CA': 2, 'FC': 10, 'FD': 1, 'FF': 3, 'FS': 9,...
# 4751            5.4  {'A': 4, 'CA': 3, 'FC': 20, 'FD': 12, 'FF': 6,...
# 9479            5.2  {'A': 4, 'CA': 4, 'FC': 21, 'FD': 12, 'FF': 13...
# 5747            5.0  {'A': 2, 'CA': 1, 'FC': 5, 'FD': 7, 'FF': 13, ...
# 5711            4.9  {'FC': 1, 'FD': 1, 'FF': 1, 'FS': 3, 'I': 1, '...
# 2159            4.8  {'A': 1, 'CA': 2, 'FC': 7, 'FD': 7, 'FF': 5, '...
# 2519            4.4  {'CA': 1, 'FC': 14, 'FF': 1, 'FS': 4, 'PE': 15...
# 1907            4.0  {'CA': 3, 'FC': 8, 'FD': 2, 'FF': 10, 'FS': 3,...
# 2003            3.9  {'A': 2, 'CA': 4, 'FC': 19, 'FD': 1, 'FF': 4, ...
# 1271            3.7  {'A': 1, 'CA': 4, 'FC': 19, 'FD': 7, 'FF': 8, ...
# 5771            3.7  {'A': 1, 'CA': 2, 'FC': 17, 'FF': 3, 'FS': 10,...
# ...             ...                                                ...
# 2196            1.6  {'A': 1, 'CA': 2, 'FC': 13, 'FD': 10, 'FF': 9,...
# 2616            9.2  {'CA': 3, 'FC': 24, 'FD': 1, 'FF': 1, 'FS': 8,...
# 4992            0.0    {'CA': 2, 'FC': 11, 'FS': 3, 'PE': 15, 'RB': 9}
# 9840            0.0  {'A': 1, 'CA': 6, 'FC': 28, 'FD': 4, 'FF': 12,...
# 9408            0.0  {'CA': 1, 'FC': 2, 'FD': 1, 'FF': 5, 'FS': 6, ...
# 588             0.0  {'CA': 6, 'FC': 18, 'FD': 7, 'FF': 12, 'FS': 2...
# 1692            0.0  {'CA': 2, 'FC': 4, 'FD': 2, 'FF': 2, 'FS': 3, ...
# 96              0.0  {'A': 2, 'CA': 3, 'FC': 32, 'FD': 3, 'FF': 3, ...
# 600             0.0  {'CA': 3, 'FC': 14, 'FD': 2, 'FF': 3, 'FS': 14...
# 9624            0.4  {'A': 1, 'CA': 2, 'FC': 2, 'FD': 6, 'FF': 5, '...
# 948             0.0  {'CA': 4, 'FC': 37, 'FD': 1, 'FF': 8, 'FS': 9,...
# 9372            0.0  {'A': 1, 'CA': 6, 'CV': 1, 'FC': 27, 'FD': 3, ...
# 6468           -1.6  {'CA': 4, 'CV': 1, 'FC': 77, 'FD': 2, 'FF': 8,...
# 756             0.0                                                 {}
# 4680            0.0                                                 {}
# 4704            0.0                                                 {}
# 4872            0.0                                                 {}
# 5064            1.9      {'FC': 1, 'FD': 1, 'FF': 1, 'FS': 2, 'PE': 2}
# 5580            0.0               {'FC': 3, 'FS': 4, 'PE': 1, 'RB': 2}
# 5700            4.9  {'FC': 1, 'FD': 1, 'FF': 1, 'FS': 3, 'I': 1, '...
# 7020            0.0                                                 {}
# 7488            0.0                                                 {}
# 7536            0.0                                                 {}
# 7812            0.0                                                 {}
# 7848            0.0                        {'CV': 1, 'FC': 2, 'FD': 1}
# 8016            0.0      {'CA': 1, 'FC': 2, 'FS': 3, 'PE': 1, 'RB': 2}
# 8028            0.0                                                 {}
# 8052            0.0                                                 {}
# 8100            0.0                                                 {}
# 9360            0.0                        {'FS': 2, 'PE': 4, 'RB': 1}
#
#      posicao clube      status  em_casa
# 3083     mei   GRE    Provável        1
# 4763     mei   BAH    Provável        0
# 5603     mei   PAL    Provável        1
# 5963     mei   FLU        Nulo        0
# 1067     mei   CEA    Provável        0
# 2627     mei   PAL    Suspenso        1
# 9539     mei   FLU    Provável        0
# 2567     mei   CEA    Provável        0
# 9815     mei   CHA    Provável        0
# 2591     mei   VAS    Provável        1
# 8687     mei   CHA    Provável        0
# 5447     mei   SAO      Dúvida        0
# 8207     mei   CRU    Provável        1
# 623      mei   ATL    Provável        0
# 8159     mei   GRE      Dúvida        1
# 5483     mei   GOI    Provável        1
# 5039     mei   FOR    Provável        1
# 5279     mei   VAS      Dúvida        1
# 491      mei   CRU    Provável        1
# 3971     mei   SAO    Provável        0
# 4751     mei   ATL      Dúvida        0
# 9479     mei   SAO      Dúvida        0
# 5747     mei   COR      Dúvida        0
# 5711     mei   AVA    Provável        1
# 2159     mei   BAH    Provável        0
# 2519     mei   COR    Provável        0
# 1907     mei   VAS    Suspenso        1
# 2003     mei   CSA    Provável        1
# 1271     mei   BOT      Dúvida        0
# 5771     mei   BAH    Provável        0
# ...      ...   ...         ...      ...
# 2196     mei   ATL    Provável        0
# 2616     mei   PAL    Suspenso        1
# 4992     mei   ATL        Nulo        0
# 9840     mei   CRU    Provável        1
# 9408     mei   AVA        Nulo        1
# 588      mei   FLU    Provável        0
# 1692     mei   AVA        Nulo        1
# 96       mei   SAO  Contundido        0
# 600      mei   CSA  Contundido        1
# 9624     mei   INT    Provável        0
# 948      mei   GOI        Nulo        1
# 9372     mei   PAL    Provável        1
# 6468     mei   BAH    Provável        0
# 756      mei   VAS        Nulo        1
# 4680     mei   FLA        Nulo        0
# 4704     mei   CSA        Nulo        1
# 4872     mei   AVA        Nulo        1
# 5064     mei   VAS        Nulo        1
# 5580     mei   FOR        Nulo        1
# 5700     mei   AVA    Provável        1
# 7020     mei   GOI        Nulo        1
# 7488     mei   COR        Nulo        0
# 7536     mei   GRE        Nulo        1
# 7812     mei   INT        Nulo        0
# 7848     mei   GOI        Nulo        1
# 8016     mei   VAS        Nulo        1
# 8028     mei   ATL        Nulo        0
# 8052     mei   BOT        Nulo        0
# 8100     mei   AVA        Nulo        1
# 9360     mei   VAS        Nulo        1
#
# [3288 rows x 13 columns]

# %%
rodada26 = df_join[df_join['rodada_id'] == 25]

# %%
rodada26
# Out:
#          id  rodada_id  pontos  preco  variacao  media           apelido  \
# 11    50294         25    0.00   2.63     -0.09  -0.66         Guilherme
# 23    37614         25    2.10   4.56      0.61   1.17           Evandro
# 35    37246         25    6.30   9.74      0.69   3.69        Ney Franco
# 47    50284         25    0.70   4.21     -0.44   1.97            Wilson
# 59    50313         25    1.20   4.36     -0.32   0.86         Elicarlos
# 71    37656         25    7.00  10.71      0.31   3.22             Fábio
# 83    37655         25    0.20   2.89      0.47   0.00      Rafael Moura
# 95    50293         25    0.00   6.79      0.00   1.17           Ramires
# 107   50301         25    0.00   7.34      0.00   1.68           Everton
# 119   37657         25    0.00   6.97      0.00   4.70       Edu Dracena
# 131   37646         25    0.90   4.16     -1.13   2.36             Betão
# 143   37281         25    6.11  10.18      0.66   3.70      Mano Menezes
# 155   50324         25    0.00   9.05     -0.41   2.28            Hudson
# 167   50328         25    0.00   5.00      0.00   0.00  Marcelo Oliveira
# 179   50317         25   -0.10   7.98     -1.10   4.64        David Braz
# 191   50407         25    0.00   4.67      0.00   1.15         Marquinho
# 203   50645         25    0.00   8.43      0.00   2.54           Eduardo
# 215   51042         25    0.00   6.67      0.00   3.17             Apodi
# 227   51194         25   -2.00   3.41     -0.52   0.74    Rafael Pereira
# 239   51415         25    0.00   4.09      0.00   0.98    Roger Carvalho
# 251   50408         25    0.00   6.00      0.00   0.00             Breno
# 263   50459         25    0.00   6.34      0.00   1.92               Léo
# 275   50877         25    0.00   2.19      0.00   0.80         Pedro Ken
# 287   51495         25    9.80   7.23      0.49   2.54       Tiago Alves
# 299   51549         25   -2.80   1.72     -1.28  -2.80         Adalberto
# 311   52618         25    0.00   3.52      0.00   2.05  Anderson Martins
# 323   51413         25    0.00   8.01      0.00   9.63            Walter
# 335   51772         25   -1.30  11.52     -0.55   3.86   Everton Ribeiro
# 347   54395         25    1.20   8.35      0.08   1.57             Elias
# 359   52674         25    5.00   5.35      1.00   1.68            Gilson
# ...     ...        ...     ...    ...       ...    ...               ...
# 9551  38959         25    1.20   5.45     -0.31   2.83       Vagner Love
# 9563  42116         25    0.00   6.99      0.00   3.05           Willian
# 9575  38939         25    0.00  16.24      0.00   5.94      Daniel Alves
# 9587  39572         25    0.20   4.62     -0.58   2.22            Renato
# 9599  42145         25    6.10   9.65     -0.22   4.23            Egídio
# 9611  42477         25    0.00   4.42      0.00   2.14    Maurício Ramos
# 9623  42234         25   -2.00   7.62     -0.31   3.67            Cássio
# 9635  62023         25    0.40   5.86      0.14   0.93      D'Alessandro
# 9647  42491         25    2.40   5.67      0.20   2.75    Márcio Azevedo
# 9659  42499         25    0.00   4.62      0.00   2.77             Bruno
# 9671  42222         25   -1.30   4.81     -1.16   1.97           Osvaldo
# 9683  37662         25    0.00   7.30      0.00   4.32          Jonathan
# 9695  49673         25    0.00   6.29      0.00   4.34       Júlio César
# 9707  49675         25    4.80   9.41      0.23   4.87    Alexandre Pato
# 9719  42232         25    0.00   2.93      0.00   1.43            Amaral
# 9731  61033         25    0.00   5.52      0.00   2.48       Rodriguinho
# 9743  61228         25    0.00   1.00      0.00   0.00          Fabrício
# 9755  61149         25    1.20   5.39     -0.45   2.25             Lucca
# 9767  61985         25    2.00   2.38      0.41  -0.39            Airton
# 9779  62086         25    0.00   5.61      0.00   2.39              Pará
# 9791  62033         25    0.00   6.01      0.00   1.85         Fernandão
# 9803  62047         25    0.00   3.72      0.00  -0.53              Jean
# 9815  62009         25    8.00   7.35      0.65   2.64            Camilo
# 9827  38140         25    5.00   7.07     -0.93   5.00    Fernando Prass
# 9839  62121         25    0.00  22.89      0.00   7.97         Vanderlei
# 9851  62104         25    0.00   5.26      0.00   0.69           Robinho
# 9863  62129         25    0.30   0.77     -0.01  -1.22        Wellington
# 9875  62968         25    0.00   5.71      0.00   2.23            Maicon
# 9887  62128         25    0.00   5.00      0.00   0.00            Walter
# 9899  49651         25    0.00  10.78      0.00   4.64           Ernando
#
#       ult_pontuacao                                              scout  \
# 11             0.00      {'CA': 2, 'FC': 4, 'FS': 3, 'PE': 6, 'RB': 2}
# 23             2.10  {'A': 2, 'CV': 1, 'FC': 12, 'FD': 1, 'FF': 1, ...
# 35             6.30                                                 {}
# 47             0.70               {'DD': 8, 'FS': 1, 'GS': 9, 'PE': 2}
# 59             1.20  {'CA': 4, 'FC': 18, 'FD': 2, 'FF': 7, 'FS': 14...
# 71             7.00  {'CA': 2, 'DD': 27, 'DP': 2, 'FS': 3, 'GS': 27...
# 83             0.20  {'CA': 1, 'FC': 24, 'FD': 2, 'FF': 4, 'FS': 13...
# 95             0.00      {'FC': 2, 'FF': 1, 'FS': 2, 'PE': 1, 'RB': 2}
# 107            0.00  {'A': 2, 'CA': 3, 'FC': 32, 'FD': 3, 'FF': 3, ...
# 119            0.00  {'FC': 3, 'FD': 1, 'FF': 3, 'FS': 2, 'PE': 1, ...
# 131            0.90  {'CA': 5, 'CV': 1, 'FC': 14, 'FD': 1, 'FF': 2,...
# 143            6.11                                                 {}
# 155            0.00  {'A': 1, 'CA': 3, 'FC': 25, 'FD': 4, 'FF': 1, ...
# 167            0.00                                                 {}
# 179           -0.10  {'FC': 8, 'FD': 2, 'FF': 7, 'FS': 1, 'G': 2, '...
# 191            0.00  {'FC': 9, 'FD': 2, 'FF': 1, 'FS': 3, 'I': 1, '...
# 203            0.00  {'A': 1, 'CA': 2, 'FC': 17, 'FS': 19, 'PE': 46...
# 215            0.00  {'A': 1, 'CA': 3, 'FC': 36, 'FD': 8, 'FF': 8, ...
# 227           -2.00  {'CA': 3, 'FC': 2, 'FS': 3, 'G': 1, 'PE': 14, ...
# 239            0.00  {'FC': 5, 'FF': 3, 'FS': 3, 'PE': 24, 'RB': 5,...
# 251            0.00                                                 {}
# 263            0.00  {'CA': 1, 'FC': 16, 'FS': 4, 'PE': 15, 'RB': 1...
# 275            0.00     {'CA': 2, 'FC': 9, 'FS': 11, 'PE': 6, 'RB': 8}
# 287            9.80  {'A': 1, 'CA': 1, 'FC': 12, 'FD': 1, 'FF': 2, ...
# 299           -2.80                        {'CA': 1, 'FC': 1, 'PE': 1}
# 311            0.00  {'CA': 5, 'FC': 12, 'FS': 1, 'PE': 12, 'RB': 1...
# 323            0.00      {'DD': 7, 'FS': 1, 'GS': 1, 'PE': 2, 'SG': 2}
# 335           -1.30  {'A': 5, 'CA': 3, 'FC': 20, 'FD': 8, 'FF': 12,...
# 347            1.20  {'A': 1, 'CA': 2, 'CV': 1, 'FC': 24, 'FD': 5, ...
# 359            5.00  {'A': 1, 'CA': 3, 'CV': 2, 'FC': 20, 'FF': 1, ...
# ...             ...                                                ...
# 9551           1.20  {'CA': 3, 'FC': 24, 'FD': 4, 'FF': 7, 'FS': 30...
# 9563           0.00  {'CA': 1, 'CV': 1, 'FC': 7, 'FD': 5, 'FS': 12,...
# 9575           0.00  {'A': 1, 'CA': 1, 'FC': 21, 'FD': 3, 'FF': 7, ...
# 9587           0.20     {'FD': 3, 'FF': 3, 'FS': 11, 'PE': 4, 'RB': 2}
# 9599           6.10  {'A': 1, 'CA': 1, 'FC': 20, 'FD': 7, 'FF': 5, ...
# 9611           0.00  {'FC': 13, 'FD': 2, 'FF': 1, 'FS': 8, 'PE': 13...
# 9623          -2.00  {'CA': 5, 'DD': 23, 'FS': 4, 'GS': 15, 'PE': 9...
# 9635           0.40  {'A': 1, 'CA': 2, 'FC': 2, 'FD': 6, 'FF': 5, '...
# 9647           2.40  {'A': 2, 'CA': 3, 'FC': 21, 'FD': 1, 'FF': 4, ...
# 9659           0.00  {'CA': 1, 'CV': 1, 'FC': 7, 'FF': 1, 'FS': 5, ...
# 9671          -1.30  {'A': 3, 'CA': 2, 'CV': 1, 'FC': 20, 'FD': 4, ...
# 9683           0.00  {'CA': 2, 'FC': 4, 'FD': 1, 'FS': 3, 'G': 1, '...
# 9695           0.00             {'DD': 17, 'GS': 13, 'PE': 1, 'SG': 2}
# 9707           4.80  {'CA': 1, 'FC': 11, 'FD': 7, 'FF': 17, 'FS': 2...
# 9719           0.00               {'FC': 4, 'FS': 2, 'PE': 3, 'RB': 7}
# 9731           0.00  {'CA': 2, 'FC': 3, 'FD': 1, 'FF': 3, 'FS': 7, ...
# 9743           0.00                                                 {}
# 9755           1.20  {'CA': 1, 'FC': 14, 'FD': 9, 'FF': 6, 'FS': 21...
# 9767           2.00  {'CA': 2, 'CV': 1, 'FC': 10, 'FS': 11, 'PE': 7...
# 9779           0.00  {'CA': 3, 'FC': 10, 'FS': 5, 'PE': 10, 'RB': 1...
# 9791           0.00  {'CA': 1, 'CV': 1, 'FC': 8, 'FD': 7, 'FF': 15,...
# 9803           0.00                                 {'FC': 2, 'PE': 2}
# 9815           8.00  {'A': 3, 'CA': 2, 'FC': 26, 'FD': 9, 'FF': 12,...
# 9827           5.00                                          {'SG': 1}
# 9839           0.00     {'DD': 15, 'FS': 2, 'GS': 6, 'PE': 4, 'SG': 3}
# 9851           0.00  {'A': 1, 'CA': 6, 'FC': 28, 'FD': 4, 'FF': 12,...
# 9863           0.30  {'CA': 7, 'FC': 31, 'FD': 1, 'FF': 2, 'FS': 6,...
# 9875           0.00  {'A': 2, 'CA': 1, 'FC': 6, 'FD': 1, 'FF': 1, '...
# 9887           0.00                                                 {}
# 9899           0.00  {'FC': 2, 'FS': 4, 'FT': 1, 'G': 1, 'PE': 3, '...
#
#      posicao clube      status  em_casa
# 11       mei   FLU        Nulo        0
# 23       mei   SAN    Provável        1
# 35       tec   GOI    Provável        1
# 47       gol   ATL      Dúvida        0
# 59       mei   CHA    Provável        0
# 71       gol   CRU    Provável        1
# 83       ata   GOI    Provável        1
# 95       mei   PAL  Contundido        1
# 107      mei   SAO  Contundido        0
# 119      zag   PAL        Nulo        1
# 131      zag   AVA    Provável        1
# 143      tec   PAL    Provável        1
# 155      mei   SAO        Nulo        0
# 167      zag   GRE  Contundido        1
# 179      zag   GRE      Dúvida        1
# 191      mei   VAS        Nulo        1
# 203      lat   CHA  Contundido        0
# 215      lat   CSA      Dúvida        1
# 227      zag   CHA    Suspenso        0
# 239      zag   FOR  Contundido        1
# 251      zag   VAS        Nulo        1
# 263      zag   CRU  Contundido        1
# 275      mei   CEA        Nulo        0
# 287      zag   CEA      Dúvida        0
# 299      zag   FOR        Nulo        1
# 311      zag   SAO        Nulo        0
# 323      gol   COR        Nulo        0
# 335      mei   FLA    Suspenso        0
# 347      mei   ATL    Provável        0
# 359      lat   BOT      Dúvida        0
# ...      ...   ...         ...      ...
# 9551     ata   COR    Provável        0
# 9563     ata   PAL    Provável        1
# 9575     lat   SAO      Dúvida        0
# 9587     ata   CHA        Nulo        0
# 9599     lat   CRU    Provável        1
# 9611     zag   CHA        Nulo        0
# 9623     gol   COR    Provável        0
# 9635     mei   INT    Provável        0
# 9647     lat   ATL    Provável        0
# 9659     lat   INT        Nulo        0
# 9671     ata   FOR    Provável        1
# 9683     lat   ATL  Contundido        0
# 9695     gol   GRE        Nulo        1
# 9707     ata   SAO    Provável        0
# 9719     mei   CHA        Nulo        0
# 9731     mei   CRU  Contundido        1
# 9743     gol   CSA        Nulo        1
# 9755     ata   BAH      Dúvida        0
# 9767     mei   FLU        Nulo        0
# 9779     lat   SAN        Nulo        1
# 9791     ata   BAH        Nulo        0
# 9803     mei   PAL        Nulo        1
# 9815     mei   CHA    Provável        0
# 9827     gol   PAL        Nulo        1
# 9839     gol   SAN        Nulo        1
# 9851     mei   CRU    Provável        1
# 9863     mei   ATL    Provável        0
# 9875     ata   ATL        Nulo        0
# 9887     ata   GOI    Suspenso        1
# 9899     zag   BAH        Nulo        0
#
# [825 rows x 13 columns]

# %%
rodada26 = rodada26[rodada26.status == 'Provável']

# %%
rodada26.sort_values(by='pontos', ascending=False).head()
# Out:
#          id  rodada_id  pontos  preco  variacao  media       apelido  \
# 2639  78850         25    20.7  17.51      2.93   6.78      Reinaldo
# 8591  38509         25    17.5  10.11      3.29   4.96   Diego Alves
# 1655  69041         25    14.5   8.26      1.44   5.50        Muriel
# 647   63013         25    12.3  17.25      1.11   6.10  Marcos Rocha
# 2447  78445         25    12.2   9.56      1.27   4.74          Renê
#
#       ult_pontuacao                                              scout  \
# 2639           20.7  {'A': 1, 'CA': 4, 'FC': 28, 'FD': 7, 'FF': 18,...
# 8591           17.5  {'DD': 26, 'DP': 2, 'FS': 3, 'GS': 17, 'PE': 1...
# 1655           14.5  {'CA': 1, 'DD': 24, 'FC': 1, 'FS': 5, 'GS': 12...
# 647            12.3  {'A': 1, 'CA': 2, 'FC': 29, 'FD': 1, 'FF': 4, ...
# 2447           12.2  {'A': 2, 'CA': 2, 'FC': 15, 'FD': 2, 'FF': 2, ...
#
#      posicao clube    status  em_casa
# 2639     lat   SAO  Provável        0
# 8591     gol   FLA  Provável        0
# 1655     gol   FLU  Provável        0
# 647      lat   PAL  Provável        1
# 2447     lat   FLA  Provável        0

# %%
lista = []
for i in rodada26.index:
    if rodada26.pontos[i]>4:
        if rodada26.preco[i]<25:
            if rodada26.variacao[i]>1:
                if rodada26.media[i]>2:
                    lista.append(1)
                else:
                    lista.append(0)
            else:
                lista.append(0)
        else:
            lista.append(0)
    else:
        lista.append(0)
                
            
            
rodada26['titular'] = lista
# Out:
# C:\Users\robson.macedo\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
rodada26[rodada26.titular == 1].head()
# Out:
#          id  rodada_id  pontos  preco  variacao  media          apelido  \
# 623   63219         25     7.2   8.40      1.30   3.65             Luan
# 647   63013         25    12.3  17.25      1.11   6.10     Marcos Rocha
# 935   68872         25     5.5  11.18      1.08   3.92    Marcelo Lomba
# 1067  71844         25     9.5  13.03      1.24   6.08  Thiago Galhardo
# 1079  71882         25    11.0  11.62      1.97   3.75      Diogo Silva
#
#       ult_pontuacao                                              scout  \
# 623             7.2  {'A': 1, 'CA': 4, 'FC': 26, 'FD': 4, 'FF': 13,...
# 647            12.3  {'A': 1, 'CA': 2, 'FC': 29, 'FD': 1, 'FF': 4, ...
# 935             5.5  {'CA': 1, 'DD': 29, 'FS': 7, 'GS': 21, 'PE': 2...
# 1067            9.5  {'A': 1, 'CA': 2, 'FC': 25, 'FD': 17, 'FF': 24...
# 1079           11.0  {'CA': 2, 'DD': 37, 'FS': 9, 'GS': 24, 'PE': 1...
#
#      posicao clube    status  em_casa  titular  tam_scout
# 623      mei   ATL  Provável        0        1         11
# 647      lat   PAL  Provável        1        1         11
# 935      gol   INT  Provável        0        1          6
# 1067     mei   CEA  Provável        0        1         12
# 1079     gol   CEA  Provável        0        1          6

# %%
lista_scout = []
for i in rodada26.scout:
    lista_scout.append(len(i))
rodada26['tam_scout'] = lista_scout
# Out:
# C:\Users\robson.macedo\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
from sklearn.model_selection import train_test_split

# %%
rodada26.columns
# Out:
# Index(['id', 'rodada_id', 'pontos', 'preco', 'variacao', 'media', 'apelido',
#        'ult_pontuacao', 'scout', 'posicao', 'clube', 'status', 'em_casa',
#        'titular', 'tam_scout'],
#       dtype='object')

# %%
previsores = ['pontos', 'preco', 'variacao', 'media','ult_pontuacao','tam_scout' ,'em_casa']

# %%
X = rodada26.loc[:, previsores]
y = rodada26.loc[:, 'titular']

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size = 0.40)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
modelo = RandomForestClassifier(n_estimators=100, n_jobs=1)

# %%
modelo.fit(X_treino, y_treino)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
pred = modelo.predict(X_teste)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_teste, pred)
# Out:
# 0.9651162790697675

# %%
rodada26[rodada26.titular ==1]
# Out:
#           id  rodada_id  pontos  preco  variacao  media          apelido  \
# 623    63219         25    7.20   8.40      1.30   3.65             Luan
# 647    63013         25   12.30  17.25      1.11   6.10     Marcos Rocha
# 935    68872         25    5.50  11.18      1.08   3.92    Marcelo Lomba
# 1067   71844         25    9.50  13.03      1.24   6.08  Thiago Galhardo
# 1079   71882         25   11.00  11.62      1.97   3.75      Diogo Silva
# 1283   72359         25   11.10  10.08      1.08   2.25      Luiz Otávio
# 1631   73421         25   10.60  13.30      1.59   5.46       Rafael Vaz
# 1655   69041         25   14.50   8.26      1.44   5.50           Muriel
# 2063   80748         25    6.60   7.35      1.23   2.87         Di Santo
# 2075   70916         25    9.70  14.55      1.36   5.62    Diogo Barbosa
# 2447   78445         25   12.20   9.56      1.27   4.74             Renê
# 2591   80196         25    7.50   9.69      1.01   2.33     Yago Pikachu
# 2639   78850         25   20.70  17.51      2.93   6.78         Reinaldo
# 3083   81845         25   11.40   9.23      1.72   5.87          Alisson
# 3311   82453         25   11.00  16.34      1.23   6.73            Tadeu
# 4427   90118         25    6.50   2.58      1.27   2.13       Yago Rocha
# 4763   91102         25   11.10   4.79      1.70   2.15           Flávio
# 5603   87999         25   10.50   6.48      1.18   3.46   Gustavo Scarpa
# 5711  101889         25    4.90   3.02      1.54   3.20    Igor Goularte
# 8135   38162         25    7.40   6.89      1.26   2.32             Fred
# 8555   99392         25   11.80   9.61      1.60   4.61          Michael
# 8591   38509         25   17.50  10.11      3.29   4.96      Diego Alves
# 8603   38505         25    6.20  10.23      1.27   4.10   Leandro Castan
# 9311  104649         25    9.20   3.08      1.63   3.29           Heitor
# 9455   41258         25    7.18  10.51      1.27   4.01  Adilson Batista
#
#       ult_pontuacao                                              scout  \
# 623            7.20  {'A': 1, 'CA': 4, 'FC': 26, 'FD': 4, 'FF': 13,...
# 647           12.30  {'A': 1, 'CA': 2, 'FC': 29, 'FD': 1, 'FF': 4, ...
# 935            5.50  {'CA': 1, 'DD': 29, 'FS': 7, 'GS': 21, 'PE': 2...
# 1067           9.50  {'A': 1, 'CA': 2, 'FC': 25, 'FD': 17, 'FF': 24...
# 1079          11.00  {'CA': 2, 'DD': 37, 'FS': 9, 'GS': 24, 'PE': 1...
# 1283          11.10  {'A': 1, 'CA': 5, 'FC': 21, 'FD': 1, 'FF': 2, ...
# 1631          10.60  {'FC': 6, 'FD': 6, 'FF': 9, 'FS': 9, 'G': 4, '...
# 1655          14.50  {'CA': 1, 'DD': 24, 'FC': 1, 'FS': 5, 'GS': 12...
# 2063           6.60  {'CA': 1, 'FC': 7, 'FD': 4, 'FF': 2, 'FS': 3, ...
# 2075           9.70  {'A': 1, 'CA': 2, 'FC': 25, 'FD': 2, 'FF': 3, ...
# 2447          12.20  {'A': 2, 'CA': 2, 'FC': 15, 'FD': 2, 'FF': 2, ...
# 2591           7.50  {'A': 1, 'CA': 5, 'FC': 15, 'FD': 4, 'FF': 15,...
# 2639          20.70  {'A': 1, 'CA': 4, 'FC': 28, 'FD': 7, 'FF': 18,...
# 3083          11.40  {'A': 5, 'CA': 4, 'FC': 14, 'FD': 8, 'FF': 6, ...
# 3311          11.00  {'DD': 51, 'DP': 2, 'FS': 6, 'GS': 28, 'PE': 1...
# 4427           6.50  {'CA': 1, 'CV': 1, 'FC': 10, 'FS': 8, 'PE': 16...
# 4763          11.10  {'CA': 2, 'FC': 28, 'FD': 1, 'FF': 5, 'FS': 13...
# 5603          10.50  {'A': 3, 'CA': 1, 'FC': 12, 'FD': 14, 'FF': 14...
# 5711           4.90  {'FC': 1, 'FD': 1, 'FF': 1, 'FS': 3, 'I': 1, '...
# 8135           7.40  {'A': 3, 'CA': 7, 'FC': 26, 'FD': 12, 'FF': 8,...
# 8555          11.80  {'A': 2, 'CA': 2, 'FC': 22, 'FD': 19, 'FF': 21...
# 8591          17.50  {'DD': 26, 'DP': 2, 'FS': 3, 'GS': 17, 'PE': 1...
# 8603           6.20  {'A': 1, 'CA': 6, 'FC': 12, 'FD': 2, 'FF': 2, ...
# 9311           9.20  {'A': 1, 'CA': 1, 'FC': 8, 'FD': 3, 'FF': 2, '...
# 9455           7.18                                                 {}
#
#      posicao clube    status  em_casa  titular  tam_scout
# 623      mei   ATL  Provável        0        1         11
# 647      lat   PAL  Provável        1        1         11
# 935      gol   INT  Provável        0        1          6
# 1067     mei   CEA  Provável        0        1         12
# 1079     gol   CEA  Provável        0        1          6
# 1283     zag   CEA  Provável        0        1          9
# 1631     zag   GOI  Provável        1        1          9
# 1655     gol   FLU  Provável        0        1          7
# 2063     ata   ATL  Provável        0        1          9
# 2075     lat   PAL  Provável        1        1          9
# 2447     lat   FLA  Provável        0        1          9
# 2591     mei   VAS  Provável        1        1         12
# 2639     lat   SAO  Provável        0        1         12
# 3083     mei   GRE  Provável        1        1          9
# 3311     gol   GOI  Provável        1        1          6
# 4427     lat   GOI  Provável        1        1          7
# 4763     mei   BAH  Provável        0        1          8
# 5603     mei   PAL  Provável        1        1          9
# 5711     mei   AVA  Provável        1        1          7
# 8135     ata   CRU  Provável        1        1         11
# 8555     ata   GOI  Provável        1        1         11
# 8591     gol   FLA  Provável        0        1          7
# 8603     zag   VAS  Provável        1        1         11
# 9311     lat   INT  Provável        0        1          9
# 9455     tec   CEA  Provável        0        1          0

# %%
atletas_df
# Out:
#         id           apelido  ult_pontuacao  \
# 0    50294         Guilherme           0.00
# 1    37614           Evandro           2.10
# 2    37246        Ney Franco           6.30
# 3    50284            Wilson           0.70
# 4    50313         Elicarlos           1.20
# 5    37656             Fábio           7.00
# 6    37655      Rafael Moura           0.20
# 7    50293           Ramires           0.00
# 8    50301           Everton           0.00
# 9    37657       Edu Dracena           0.00
# 10   37646             Betão           0.90
# 11   37281      Mano Menezes           6.11
# 12   50324            Hudson           0.00
# 13   50328  Marcelo Oliveira           0.00
# 14   50317        David Braz          -0.10
# 15   50407         Marquinho           0.00
# 16   50645           Eduardo           0.00
# 17   51042             Apodi           0.00
# 18   51194    Rafael Pereira          -2.00
# 19   51415    Roger Carvalho           0.00
# 20   50408             Breno           0.00
# 21   50459               Léo           0.00
# 22   50877         Pedro Ken           0.00
# 23   51495       Tiago Alves           9.80
# 24   51549         Adalberto          -2.80
# 25   52618  Anderson Martins           0.00
# 26   51413            Walter           0.00
# 27   51772   Everton Ribeiro          -1.30
# 28   54395             Elias           1.20
# 29   52674            Gilson           5.00
# ..     ...               ...            ...
# 795  38959       Vagner Love           1.20
# 796  42116           Willian           0.00
# 797  38939      Daniel Alves           0.00
# 798  39572            Renato           0.20
# 799  42145            Egídio           6.10
# 800  42477    Maurício Ramos           0.00
# 801  42234            Cássio          -2.00
# 802  62023      D'Alessandro           0.40
# 803  42491    Márcio Azevedo           2.40
# 804  42499             Bruno           0.00
# 805  42222           Osvaldo          -1.30
# 806  37662          Jonathan           0.00
# 807  49673       Júlio César           0.00
# 808  49675    Alexandre Pato           4.80
# 809  42232            Amaral           0.00
# 810  61033       Rodriguinho           0.00
# 811  61228          Fabrício           0.00
# 812  61149             Lucca           1.20
# 813  61985            Airton           2.00
# 814  62086              Pará           0.00
# 815  62033         Fernandão           0.00
# 816  62047              Jean           0.00
# 817  62009            Camilo           8.00
# 818  38140    Fernando Prass           5.00
# 819  62121         Vanderlei           0.00
# 820  62104           Robinho           0.00
# 821  62129        Wellington           0.30
# 822  62968            Maicon           0.00
# 823  62128            Walter           0.00
# 824  49651           Ernando           0.00
#
#                                                  scout posicao clube  \
# 0        {'CA': 2, 'FC': 4, 'FS': 3, 'PE': 6, 'RB': 2}     mei   FLU
# 1    {'A': 2, 'CV': 1, 'FC': 12, 'FD': 1, 'FF': 1, ...     mei   SAN
# 2                                                   {}     tec   GOI
# 3                 {'DD': 8, 'FS': 1, 'GS': 9, 'PE': 2}     gol   ATL
# 4    {'CA': 4, 'FC': 18, 'FD': 2, 'FF': 7, 'FS': 14...     mei   CHA
# 5    {'CA': 2, 'DD': 27, 'DP': 2, 'FS': 3, 'GS': 27...     gol   CRU
# 6    {'CA': 1, 'FC': 24, 'FD': 2, 'FF': 4, 'FS': 13...     ata   GOI
# 7        {'FC': 2, 'FF': 1, 'FS': 2, 'PE': 1, 'RB': 2}     mei   PAL
# 8    {'A': 2, 'CA': 3, 'FC': 32, 'FD': 3, 'FF': 3, ...     mei   SAO
# 9    {'FC': 3, 'FD': 1, 'FF': 3, 'FS': 2, 'PE': 1, ...     zag   PAL
# 10   {'CA': 5, 'CV': 1, 'FC': 14, 'FD': 1, 'FF': 2,...     zag   AVA
# 11                                                  {}     tec   PAL
# 12   {'A': 1, 'CA': 3, 'FC': 25, 'FD': 4, 'FF': 1, ...     mei   SAO
# 13                                                  {}     zag   GRE
# 14   {'FC': 8, 'FD': 2, 'FF': 7, 'FS': 1, 'G': 2, '...     zag   GRE
# 15   {'FC': 9, 'FD': 2, 'FF': 1, 'FS': 3, 'I': 1, '...     mei   VAS
# 16   {'A': 1, 'CA': 2, 'FC': 17, 'FS': 19, 'PE': 46...     lat   CHA
# 17   {'A': 1, 'CA': 3, 'FC': 36, 'FD': 8, 'FF': 8, ...     lat   CSA
# 18   {'CA': 3, 'FC': 2, 'FS': 3, 'G': 1, 'PE': 14, ...     zag   CHA
# 19   {'FC': 5, 'FF': 3, 'FS': 3, 'PE': 24, 'RB': 5,...     zag   FOR
# 20                                                  {}     zag   VAS
# 21   {'CA': 1, 'FC': 16, 'FS': 4, 'PE': 15, 'RB': 1...     zag   CRU
# 22      {'CA': 2, 'FC': 9, 'FS': 11, 'PE': 6, 'RB': 8}     mei   CEA
# 23   {'A': 1, 'CA': 1, 'FC': 12, 'FD': 1, 'FF': 2, ...     zag   CEA
# 24                         {'CA': 1, 'FC': 1, 'PE': 1}     zag   FOR
# 25   {'CA': 5, 'FC': 12, 'FS': 1, 'PE': 12, 'RB': 1...     zag   SAO
# 26       {'DD': 7, 'FS': 1, 'GS': 1, 'PE': 2, 'SG': 2}     gol   COR
# 27   {'A': 5, 'CA': 3, 'FC': 20, 'FD': 8, 'FF': 12,...     mei   FLA
# 28   {'A': 1, 'CA': 2, 'CV': 1, 'FC': 24, 'FD': 5, ...     mei   ATL
# 29   {'A': 1, 'CA': 3, 'CV': 2, 'FC': 20, 'FF': 1, ...     lat   BOT
# ..                                                 ...     ...   ...
# 795  {'CA': 3, 'FC': 24, 'FD': 4, 'FF': 7, 'FS': 30...     ata   COR
# 796  {'CA': 1, 'CV': 1, 'FC': 7, 'FD': 5, 'FS': 12,...     ata   PAL
# 797  {'A': 1, 'CA': 1, 'FC': 21, 'FD': 3, 'FF': 7, ...     lat   SAO
# 798     {'FD': 3, 'FF': 3, 'FS': 11, 'PE': 4, 'RB': 2}     ata   CHA
# 799  {'A': 1, 'CA': 1, 'FC': 20, 'FD': 7, 'FF': 5, ...     lat   CRU
# 800  {'FC': 13, 'FD': 2, 'FF': 1, 'FS': 8, 'PE': 13...     zag   CHA
# 801  {'CA': 5, 'DD': 23, 'FS': 4, 'GS': 15, 'PE': 9...     gol   COR
# 802  {'A': 1, 'CA': 2, 'FC': 2, 'FD': 6, 'FF': 5, '...     mei   INT
# 803  {'A': 2, 'CA': 3, 'FC': 21, 'FD': 1, 'FF': 4, ...     lat   ATL
# 804  {'CA': 1, 'CV': 1, 'FC': 7, 'FF': 1, 'FS': 5, ...     lat   INT
# 805  {'A': 3, 'CA': 2, 'CV': 1, 'FC': 20, 'FD': 4, ...     ata   FOR
# 806  {'CA': 2, 'FC': 4, 'FD': 1, 'FS': 3, 'G': 1, '...     lat   ATL
# 807             {'DD': 17, 'GS': 13, 'PE': 1, 'SG': 2}     gol   GRE
# 808  {'CA': 1, 'FC': 11, 'FD': 7, 'FF': 17, 'FS': 2...     ata   SAO
# 809               {'FC': 4, 'FS': 2, 'PE': 3, 'RB': 7}     mei   CHA
# 810  {'CA': 2, 'FC': 3, 'FD': 1, 'FF': 3, 'FS': 7, ...     mei   CRU
# 811                                                 {}     gol   CSA
# 812  {'CA': 1, 'FC': 14, 'FD': 9, 'FF': 6, 'FS': 21...     ata   BAH
# 813  {'CA': 2, 'CV': 1, 'FC': 10, 'FS': 11, 'PE': 7...     mei   FLU
# 814  {'CA': 3, 'FC': 10, 'FS': 5, 'PE': 10, 'RB': 1...     lat   SAN
# 815  {'CA': 1, 'CV': 1, 'FC': 8, 'FD': 7, 'FF': 15,...     ata   BAH
# 816                                 {'FC': 2, 'PE': 2}     mei   PAL
# 817  {'A': 3, 'CA': 2, 'FC': 26, 'FD': 9, 'FF': 12,...     mei   CHA
# 818                                          {'SG': 1}     gol   PAL
# 819     {'DD': 15, 'FS': 2, 'GS': 6, 'PE': 4, 'SG': 3}     gol   SAN
# 820  {'A': 1, 'CA': 6, 'FC': 28, 'FD': 4, 'FF': 12,...     mei   CRU
# 821  {'CA': 7, 'FC': 31, 'FD': 1, 'FF': 2, 'FS': 6,...     mei   ATL
# 822  {'A': 2, 'CA': 1, 'FC': 6, 'FD': 1, 'FF': 1, '...     ata   ATL
# 823                                                 {}     ata   GOI
# 824  {'FC': 2, 'FS': 4, 'FT': 1, 'G': 1, 'PE': 3, '...     zag   BAH
#
#          status  em_casa
# 0          Nulo        0
# 1      Provável        1
# 2      Provável        1
# 3        Dúvida        0
# 4      Provável        0
# 5      Provável        1
# 6      Provável        1
# 7    Contundido        1
# 8    Contundido        0
# 9          Nulo        1
# 10     Provável        1
# 11     Provável        1
# 12         Nulo        0
# 13   Contundido        1
# 14       Dúvida        1
# 15         Nulo        1
# 16   Contundido        0
# 17       Dúvida        1
# 18     Suspenso        0
# 19   Contundido        1
# 20         Nulo        1
# 21   Contundido        1
# 22         Nulo        0
# 23       Dúvida        0
# 24         Nulo        1
# 25         Nulo        0
# 26         Nulo        0
# 27     Suspenso        0
# 28     Provável        0
# 29       Dúvida        0
# ..          ...      ...
# 795    Provável        0
# 796    Provável        1
# 797      Dúvida        0
# 798        Nulo        0
# 799    Provável        1
# 800        Nulo        0
# 801    Provável        0
# 802    Provável        0
# 803    Provável        0
# 804        Nulo        0
# 805    Provável        1
# 806  Contundido        0
# 807        Nulo        1
# 808    Provável        0
# 809        Nulo        0
# 810  Contundido        1
# 811        Nulo        1
# 812      Dúvida        0
# 813        Nulo        0
# 814        Nulo        1
# 815        Nulo        0
# 816        Nulo        1
# 817    Provável        0
# 818        Nulo        1
# 819        Nulo        1
# 820    Provável        1
# 821    Provável        0
# 822        Nulo        0
# 823    Suspenso        1
# 824        Nulo        0
#
# [825 rows x 8 columns]

# %%
goleiros = df_join[df_join.posicao == 'gol']

# %%
goleiros.sort_values(by='pontos',ascending=False)
# Out:
#           id  rodada_id  pontos  preco  variacao  media            apelido  \
# 5106   86776         20    23.0  14.46      3.80   7.27              Jordi
# 1563   69040         17    22.7   9.66      3.25   4.24           Vladimir
# 3307   82453         21    21.5  17.32      2.80   6.11              Tadeu
# 1648   69041         18    19.4   7.03      4.42   3.82             Muriel
# 8581   38509         15    18.0   8.86      3.76   4.27        Diego Alves
# 8591   38509         25    17.5  10.11      3.29   4.96        Diego Alves
# 3309   82453         23    17.0  17.34      1.76   6.71              Tadeu
# 1160   72018         22    17.0  13.43      3.48   5.28        Tiago Volpi
# 2486   78584         16    16.7  16.33      2.75   8.55  Douglas Friedrich
# 1153   72018         15    16.4  12.71      3.30   5.44        Tiago Volpi
# 67     37656         21    16.0  12.28      2.61   3.51              Fábio
# 1655   69041         25    14.5   8.26      1.44   5.50             Muriel
# 9687   49673         17    14.0   7.93      1.63   4.67        Júlio César
# 1570   69040         24    14.0   8.79      2.53   4.22           Vladimir
# 1565   69040         19    14.0   8.65      2.98   4.38           Vladimir
# 2296   71043         18    13.7   4.92      1.92  13.70                Leo
# 1681   69051         15    13.7   8.12      1.93   8.85   Danilo Fernandes
# 1393   69012         15    13.4   8.60      1.88   3.78             Santos
# 1404   72372         14    12.8  10.79      2.18   4.34       Felipe Alves
# 8459   38431         25    12.7   7.31      1.19   6.53    Diego Cavalieri
# 3449   82730         19    12.5   5.43      1.43  12.50     Marcelo Rangel
# 5101   86776         15    12.2  11.53      2.88   6.26              Jordi
# 63     37656         17    12.0  11.69      2.42   3.60              Fábio
# 1155   72018         17    12.0  12.52      1.42   5.83        Tiago Volpi
# 9620   42234         22    12.0  10.08      2.46   4.32             Cássio
# 2141   74061         19    11.7  10.30      1.83   5.06   Gatito Fernández
# 5104   86776         18    11.7  12.16      1.08   6.66              Jordi
# 9615   42234         17    11.5  10.05      2.45   4.92             Cássio
# 512    37788         22    11.5   5.13      1.57   2.73      Marcelo Boeck
# 1377   72294         23    11.4   9.58      1.18   3.46            Éverson
# ...      ...        ...     ...    ...       ...    ...                ...
# 915    71631         17    -6.0  11.63     -1.87   2.76           Weverton
# 1374   72294         20    -6.3   6.49     -1.20   2.96            Éverson
# 1567   69040         21    -8.0   5.28     -2.77   3.97           Vladimir
# 36     50284         14     NaN    NaN       NaN    NaN             Wilson
# 37     50284         15     NaN    NaN       NaN    NaN             Wilson
# 38     50284         16     NaN    NaN       NaN    NaN             Wilson
# 5988   93795         14     NaN    NaN       NaN    NaN     Matheus Cabral
# 5989   93795         15     NaN    NaN       NaN    NaN     Matheus Cabral
# 5990   93795         16     NaN    NaN       NaN    NaN     Matheus Cabral
# 5991   93795         17     NaN    NaN       NaN    NaN     Matheus Cabral
# 5992   93795         18     NaN    NaN       NaN    NaN     Matheus Cabral
# 5993   93795         19     NaN    NaN       NaN    NaN     Matheus Cabral
# 5994   93795         20     NaN    NaN       NaN    NaN     Matheus Cabral
# 5995   93795         21     NaN    NaN       NaN    NaN     Matheus Cabral
# 7944  106160         14     NaN    NaN       NaN    NaN              Lucão
# 7945  106160         15     NaN    NaN       NaN    NaN              Lucão
# 7946  106160         16     NaN    NaN       NaN    NaN              Lucão
# 8280   98496         14     NaN    NaN       NaN    NaN           Vinícius
# 8281   98496         15     NaN    NaN       NaN    NaN           Vinícius
# 8282   98496         16     NaN    NaN       NaN    NaN           Vinícius
# 8352  102906         14     NaN    NaN       NaN    NaN           Anderson
# 8353  102906         15     NaN    NaN       NaN    NaN           Anderson
# 8354  102906         16     NaN    NaN       NaN    NaN           Anderson
# 8355  102906         17     NaN    NaN       NaN    NaN           Anderson
# 8356  102906         18     NaN    NaN       NaN    NaN           Anderson
# 8357  102906         19     NaN    NaN       NaN    NaN           Anderson
# 8358  102906         20     NaN    NaN       NaN    NaN           Anderson
# 8784  103524         14     NaN    NaN       NaN    NaN            Phelipe
# 8785  103524         15     NaN    NaN       NaN    NaN            Phelipe
# 8786  103524         16     NaN    NaN       NaN    NaN            Phelipe
#
#       ult_pontuacao                                              scout  \
# 5106           -2.0  {'CA': 4, 'DD': 57, 'DP': 2, 'FC': 3, 'FS': 3,...
# 1563            6.7  {'CA': 2, 'DD': 43, 'FS': 2, 'GS': 30, 'PE': 5...
# 3307           11.0  {'DD': 51, 'DP': 2, 'FS': 6, 'GS': 28, 'PE': 1...
# 1648           14.5  {'CA': 1, 'DD': 24, 'FC': 1, 'FS': 5, 'GS': 12...
# 8581           17.5  {'DD': 26, 'DP': 2, 'FS': 3, 'GS': 17, 'PE': 1...
# 8591           17.5  {'DD': 26, 'DP': 2, 'FS': 3, 'GS': 17, 'PE': 1...
# 3309           11.0  {'DD': 51, 'DP': 2, 'FS': 6, 'GS': 28, 'PE': 1...
# 1160            4.4  {'DD': 36, 'FS': 8, 'GS': 16, 'PE': 19, 'SG': 10}
# 2486           -4.0  {'DD': 42, 'DP': 1, 'FS': 5, 'GS': 20, 'PE': 7...
# 1153            4.4  {'DD': 36, 'FS': 8, 'GS': 16, 'PE': 19, 'SG': 10}
# 67              7.0  {'CA': 2, 'DD': 27, 'DP': 2, 'FS': 3, 'GS': 27...
# 1655           14.5  {'CA': 1, 'DD': 24, 'FC': 1, 'FS': 5, 'GS': 12...
# 9687            0.0             {'DD': 17, 'GS': 13, 'PE': 1, 'SG': 2}
# 1570            6.7  {'CA': 2, 'DD': 43, 'FS': 2, 'GS': 30, 'PE': 5...
# 1565            6.7  {'CA': 2, 'DD': 43, 'FS': 2, 'GS': 30, 'PE': 5...
# 2296           -4.3               {'CA': 1, 'DD': 7, 'GS': 6, 'PE': 2}
# 1681            0.0               {'DD': 8, 'GS': 2, 'PE': 1, 'SG': 1}
# 1393            0.0  {'CA': 1, 'DD': 22, 'DP': 1, 'FC': 1, 'FS': 4,...
# 1404            0.0  {'CA': 3, 'DD': 34, 'DP': 1, 'FC': 1, 'FS': 1,...
# 8459           12.7              {'DD': 18, 'FC': 1, 'GS': 7, 'PE': 1}
# 3449            0.0                        {'DD': 6, 'FS': 1, 'GS': 3}
# 5101           -2.0  {'CA': 4, 'DD': 57, 'DP': 2, 'FC': 3, 'FS': 3,...
# 63              7.0  {'CA': 2, 'DD': 27, 'DP': 2, 'FS': 3, 'GS': 27...
# 1155            4.4  {'DD': 36, 'FS': 8, 'GS': 16, 'PE': 19, 'SG': 10}
# 9620           -2.0  {'CA': 5, 'DD': 23, 'FS': 4, 'GS': 15, 'PE': 9...
# 2141            0.0  {'CA': 3, 'DD': 35, 'FS': 4, 'GS': 20, 'PE': 1...
# 5104           -2.0  {'CA': 4, 'DD': 57, 'DP': 2, 'FC': 3, 'FS': 3,...
# 9615           -2.0  {'CA': 5, 'DD': 23, 'FS': 4, 'GS': 15, 'PE': 9...
# 512             7.0  {'CA': 1, 'DD': 15, 'FS': 1, 'GS': 10, 'PE': 3...
# 1377            6.8  {'CA': 1, 'DD': 21, 'DP': 1, 'FC': 1, 'FS': 7,...
# ...             ...                                                ...
# 915             0.0    {'DD': 20, 'FS': 3, 'GS': 16, 'PE': 5, 'SG': 5}
# 1374            6.8  {'CA': 1, 'DD': 21, 'DP': 1, 'FC': 1, 'FS': 7,...
# 1567            6.7  {'CA': 2, 'DD': 43, 'FS': 2, 'GS': 30, 'PE': 5...
# 36              0.7               {'DD': 8, 'FS': 1, 'GS': 9, 'PE': 2}
# 37              0.7               {'DD': 8, 'FS': 1, 'GS': 9, 'PE': 2}
# 38              0.7               {'DD': 8, 'FS': 1, 'GS': 9, 'PE': 2}
# 5988            0.0                                                 {}
# 5989            0.0                                                 {}
# 5990            0.0                                                 {}
# 5991            0.0                                                 {}
# 5992            0.0                                                 {}
# 5993            0.0                                                 {}
# 5994            0.0                                                 {}
# 5995            0.0                                                 {}
# 7944            0.0                                                 {}
# 7945            0.0                                                 {}
# 7946            0.0                                                 {}
# 8280            0.0                                                 {}
# 8281            0.0                                                 {}
# 8282            0.0                                                 {}
# 8352            0.0                                                 {}
# 8353            0.0                                                 {}
# 8354            0.0                                                 {}
# 8355            0.0                                                 {}
# 8356            0.0                                                 {}
# 8357            0.0                                                 {}
# 8358            0.0                                                 {}
# 8784            0.0                                                 {}
# 8785            0.0                                                 {}
# 8786            0.0                                                 {}
#
#      posicao clube      status  em_casa
# 5106     gol   CSA      Dúvida        1
# 1563     gol   AVA    Provável        1
# 3307     gol   GOI    Provável        1
# 1648     gol   FLU    Provável        0
# 8581     gol   FLA    Provável        0
# 8591     gol   FLA    Provável        0
# 3309     gol   GOI    Provável        1
# 1160     gol   SAO    Provável        0
# 2486     gol   BAH    Provável        0
# 1153     gol   SAO    Provável        0
# 67       gol   CRU    Provável        1
# 1655     gol   FLU    Provável        0
# 9687     gol   GRE        Nulo        1
# 1570     gol   AVA    Provável        1
# 1565     gol   AVA    Provável        1
# 2296     gol   ATL      Dúvida        0
# 1681     gol   INT        Nulo        0
# 1393     gol   ATL      Dúvida        0
# 1404     gol   FOR  Contundido        1
# 8459     gol   BOT      Dúvida        0
# 3449     gol   GOI        Nulo        1
# 5101     gol   CSA      Dúvida        1
# 63       gol   CRU    Provável        1
# 1155     gol   SAO    Provável        0
# 9620     gol   COR    Provável        0
# 2141     gol   BOT      Dúvida        0
# 5104     gol   CSA      Dúvida        1
# 9615     gol   COR    Provável        0
# 512      gol   FOR    Provável        1
# 1377     gol   SAN    Provável        1
# ...      ...   ...         ...      ...
# 915      gol   PAL    Provável        1
# 1374     gol   SAN    Provável        1
# 1567     gol   AVA    Provável        1
# 36       gol   ATL      Dúvida        0
# 37       gol   ATL      Dúvida        0
# 38       gol   ATL      Dúvida        0
# 5988     gol   CEA        Nulo        0
# 5989     gol   CEA        Nulo        0
# 5990     gol   CEA        Nulo        0
# 5991     gol   CEA        Nulo        0
# 5992     gol   CEA        Nulo        0
# 5993     gol   CEA        Nulo        0
# 5994     gol   CEA        Nulo        0
# 5995     gol   CEA        Nulo        0
# 7944     gol   VAS        Nulo        1
# 7945     gol   VAS        Nulo        1
# 7946     gol   VAS        Nulo        1
# 8280     gol   CRU        Nulo        1
# 8281     gol   CRU        Nulo        1
# 8282     gol   CRU        Nulo        1
# 8352     gol   ATL        Nulo        0
# 8353     gol   ATL        Nulo        0
# 8354     gol   ATL        Nulo        0
# 8355     gol   ATL        Nulo        0
# 8356     gol   ATL        Nulo        0
# 8357     gol   ATL        Nulo        0
# 8358     gol   ATL        Nulo        0
# 8784     gol   GRE        Nulo        1
# 8785     gol   GRE        Nulo        1
# 8786     gol   GRE        Nulo        1
#
# [1176 rows x 13 columns]

# %%
df_join.posicao.value_counts()
# Out:
# mei    3288
# ata    2244
# zag    1560
# lat    1404
# gol    1176
# tec     228
# Name: posicao, dtype: int64

# %%
clubes = api.clubes()

# %%
id_time = []
nome = []
abreviacao = []
for i in clubes.values():
    id_time.append(i.id)
    nome.append(i.nome)
    abreviacao.append(i.abreviacao)
clubes_dict = {}
clubes_dict['id_time'] = id_time
clubes_dict['nome'] = nome
clubes_dict['abreviacao'] = abreviacao

clubes_df = pd.DataFrame(clubes_dict)

# %%
clubes_df.head()
# Out:
#    id_time      nome abreviacao
# 0        1    Outros        OUT
# 1     1349  Ipatinga        IPA
# 2     1371    Cuiabá        CUI
# 3     1390     Icasa        ICA
# 4     2190     Oeste        OES

# %%
df_join.head()
# Out:
#       id  rodada_id  pontos  preco  variacao  media    apelido  ult_pontuacao  \
# 0  50294         14     0.0   3.06       0.0   -1.1  Guilherme            0.0
# 1  50294         15     0.0   3.06       0.0   -1.1  Guilherme            0.0
# 2  50294         16     0.0   3.06       0.0   -1.1  Guilherme            0.0
# 3  50294         17     0.0   3.06       0.0   -1.1  Guilherme            0.0
# 4  50294         18     0.0   3.06       0.0   -1.1  Guilherme            0.0
#
#                                            scout posicao clube status
# 0  {'CA': 2, 'FC': 4, 'FS': 3, 'PE': 6, 'RB': 2}     mei   FLU   Nulo
# 1  {'CA': 2, 'FC': 4, 'FS': 3, 'PE': 6, 'RB': 2}     mei   FLU   Nulo
# 2  {'CA': 2, 'FC': 4, 'FS': 3, 'PE': 6, 'RB': 2}     mei   FLU   Nulo
# 3  {'CA': 2, 'FC': 4, 'FS': 3, 'PE': 6, 'RB': 2}     mei   FLU   Nulo
# 4  {'CA': 2, 'FC': 4, 'FS': 3, 'PE': 6, 'RB': 2}     mei   FLU   Nulo

# %%
partidas_df
# Out:
#                    data              local clube_casa  clube_casa_placar  \
# 0   2019-07-27 17:00:00    Arena Palmeiras        PAL                  1
# 1   2019-07-27 19:00:00          Beira-Rio        INT                  1
# 2   2019-07-27 19:00:00           Mineirão        CRU                  0
# 3   2019-07-27 19:00:00           Maracanã        FLU                  1
# 4   2019-07-28 11:00:00        Arena Condá        CHA                  0
# 5   2019-07-28 16:00:00       Vila Belmiro        SAN                  3
# 6   2019-07-28 16:00:00           Maracanã        FLA                  3
# 7   2019-07-28 19:00:00      Castelão (CE)        FOR                  1
# 8   2019-07-28 19:00:00      Serra Dourada        GOI                  0
# 9   2019-08-03 19:00:00      Castelão (CE)        CEA                  2
# 10  2019-08-03 19:00:00           Maracanã        FLU                  2
# 11  2019-08-04 11:00:00       Vila Belmiro        SAN                  6
# 12  2019-08-04 16:00:00          Ressacada        AVA                  0
# 13  2019-08-04 16:00:00         Fonte Nova        BAH                  3
# 14  2019-08-04 19:00:00      Independência        ATL                  2
# 15  2019-08-04 19:00:00  Arena Corinthians        COR                  1
# 16  2019-08-04 19:00:00     Kleber Andrade        VAS                  0
# 17  2019-08-05 20:00:00    Arena do Grêmio        GRE                  3
# 18  2019-08-10 17:00:00      Castelão (CE)        CEA                  4
# 19  2019-08-10 17:00:00            Morumbi        SAO                  3
# 20  2019-08-10 19:00:00           Maracanã        FLA                  3
# 21  2019-08-10 21:00:00      Independência        ATL                  2
# 22  2019-08-11 11:00:00          Beira-Rio        INT                  0
# 23  2019-08-11 16:00:00    Arena Palmeiras        PAL                  2
# 24  2019-08-11 16:00:00           Engenhão        BOT                  2
# 25  2019-08-11 16:00:00          Ressacada        AVA                  2
# 26  2019-08-11 19:00:00      Serra Dourada        GOI                  0
# 27  2019-08-17 17:00:00      Castelão (CE)        FOR                  0
# 28  2019-08-17 17:00:00  Arena Corinthians        COR                  2
# 29  2019-08-17 19:00:00     Mané Garrincha        VAS                  1
# ..                  ...                ...        ...                ...
# 105 2019-10-06 16:00:00      Castelão (CE)        CEA                  0
# 106 2019-10-06 16:00:00    Arena Palmeiras        PAL                  1
# 107 2019-10-06 16:00:00           Engenhão        BOT                  0
# 108 2019-10-09 19:15:00           Engenhão        BOT                  3
# 109 2019-10-09 19:15:00           Rei Pelé        CSA                  1
# 110 2019-10-09 20:30:00      Castelão (CE)        FOR                  2
# 111 2019-10-09 21:00:00         Centenário        GRE                  2
# 112 2019-10-09 21:00:00         Fonte Nova        BAH                  0
# 113 2019-10-09 21:30:00           Mineirão        CRU                  0
# 114 2019-10-09 21:30:00       Vila Belmiro        SAN                  2
# 115 2019-10-10 19:15:00  Arena Corinthians        COR                  2
# 116 2019-10-10 19:15:00          Ressacada        AVA                  0
# 117 2019-10-12 17:00:00      Serra Dourada        GOI                  1
# 118 2019-10-12 19:00:00           Maracanã        FLU                  2
# 119 2019-10-12 21:00:00           Pacaembu        PAL                  1
# 120 2019-10-13 16:00:00          Beira-Rio        INT                  0
# 121 2019-10-13 16:00:00      Castelão (CE)        CEA                  1
# 122 2019-10-13 16:00:00       São Januário        VAS                  1
# 123 2019-10-13 16:00:00   Arena da Baixada        ATL                  0
# 124 2019-10-13 18:00:00            Morumbi        SAO                  1
# 125 2019-10-13 19:00:00      Independência        ATL                  1
# 126 2019-10-16 19:15:00    Arena do Grêmio        GRE                 -1
# 127 2019-10-16 19:15:00           Rei Pelé        CSA                 -1
# 128 2019-10-16 20:00:00      Castelão (CE)        FOR                 -1
# 129 2019-10-16 21:00:00           Mineirão        CRU                 -1
# 130 2019-10-16 21:00:00    Arena Palmeiras        PAL                 -1
# 131 2019-10-16 21:30:00       São Januário        VAS                 -1
# 132 2019-10-16 21:30:00      Serra Dourada        GOI                 -1
# 133 2019-10-17 19:15:00       Vila Belmiro        SAN                 -1
# 134 2019-10-17 19:15:00          Ressacada        AVA                 -1
#
#     clube_visitante  clube_visitante_placar
# 0               VAS                       1
# 1               CEA                       0
# 2               ATL                       2
# 3               SAO                       2
# 4               BAH                       0
# 5               AVA                       1
# 6               BOT                       2
# 7               COR                       3
# 8               ATL                       0
# 9               FOR                       1
# 10              INT                       1
# 11              GOI                       1
# 12              BOT                       2
# 13              FLA                       0
# 14              CRU                       0
# 15              PAL                       1
# 16              CSA                       0
# 17              CHA                       3
# 18              CHA                       1
# 19              SAN                       2
# 20              GRE                       1
# 21              FLU                       1
# 22              COR                       0
# 23              BAH                       2
# 24              ATL                       1
# 25              CRU                       2
# 26              VAS                       1
# 27              INT                       1
# 28              BOT                       0
# 29              FLA                       4
# ..              ...                     ...
# 105             GOI                       1
# 106             ATL                       1
# 107             FLU                       1
# 108             GOI                       1
# 109             INT                       0
# 110             CHA                       0
# 111             CEA                       1
# 112             SAO                       0
# 113             FLU                       0
# 114             PAL                       0
# 115             ATL                       2
# 116             VAS                       0
# 117             CSA                       0
# 118             BAH                       0
# 119             BOT                       0
# 120             SAN                       0
# 121             AVA                       0
# 122             FOR                       0
# 123             FLA                       2
# 124             COR                       0
# 125             GRE                       4
# 126             BAH                      -1
# 127             ATL                      -1
# 128             FLA                      -1
# 129             SAO                      -1
# 130             CHA                      -1
# 131             BOT                      -1
# 132             COR                      -1
# 133             CEA                      -1
# 134             INT                      -1
#
# [135 rows x 6 columns]

# %%
## Treinando com todos os dados
